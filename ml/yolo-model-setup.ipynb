# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.0 MB/s eta 0:00:00a 0:00:01

# %%
from ultralytics import YOLO

model = YOLO('/kaggle/input/jetarm-yolo11n/yolo11n.pt')
print('Model loaded successfully')
print('Classes:', model.names)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_55/1737126790.py in <cell line: 0>()
#       1 from ultralytics import YOLO
#       2
# ----> 3 model = YOLO('/kaggle/input/jetarm-yolo11n/yolo11n.pt')
#       4 print('Model loaded successfully')
#       5 print('Classes:', model.names)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      74         else:
#      75             # Continue with default YOLO initialization
# ...

# %%
import shutil
from ultralytics import YOLO

# Copy from read-only input to writable working directory
shutil.copy('/kaggle/input/jetarm-yolo11n/yolo11n.pt', '/kaggle/working/yolo11n.pt')

model = YOLO('/kaggle/working/yolo11n.pt')
print('Model loaded successfully')
print('Classes:', model.names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_55/63310893.py in <cell line: 0>()
#       3
#       4 # Copy from read-only input to writable working directory
# ----> 5 shutil.copy('/kaggle/input/jetarm-yolo11n/yolo11n.pt', '/kaggle/working/yolo11n.pt')
#       6
#       7 model = YOLO('/kaggle/working/yolo11n.pt')
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
# ...

# %%
import os
print(os.listdir('/kaggle/input/datasets/ashtonmears/jetarm-yolo'))
# Out:
# ['yolo11n.pt']

# %%
import shutil
from ultralytics import YOLO

shutil.copy('/kaggle/input/datasets/ashtonmears/jetarm-yolo/yolo11n.pt', '/kaggle/working/yolo11n.pt')

model = YOLO('/kaggle/working/yolo11n.pt')
print('Model loaded successfully')
print('Classes:', model.names)
# Out:
# Model loaded successfully
# ...
